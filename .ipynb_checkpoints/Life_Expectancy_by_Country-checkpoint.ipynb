# %%
# Dependencies and Setup
#import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import time
import json
import requests
import pymysql
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
pymysql.install_as_MySQLdb()

# %%
# Build query Url
url = "http://api.worldbank.org/v2/country/"
countries = ["ken","nga","gha","eth","rwa"]

# %%
# Create and initialize list 
# Setup dictionary to convert to df
country = []
indicator = []
year = []
percent = []

for i in countries:
    url_get = url + i +"/indicator/SP.DYN.LE00.IN?format=json"
    response = requests.get(url_get)
    data_1 = response.json()
    print(i)

    for item in data_1[1]:
        country.append(item['country']['value'])
        year.append(item['date'])
        indicator.append(item['indicator']['value'])
        percent.append(item['value'])
        print(item)
    with open(f'Resources/data/output_api_2.json', 'w') as outfile:json.dump({'country':country, 'indicator':indicator, 'year':year, 'percent':percent}, outfile)
# Out:
# ken
# {'indicator': {'id': 'SP.DYN.LE00.IN', 'value': 'Life expectancy at birth, total (years)'}, 'country': {'id': 'KE', 'value': 'Kenya'}, 'countryiso3code': 'KEN', 'date': '2018', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}
# {'indicator': {'id': 'SP.DYN.LE00.IN', 'value': 'Life expectancy at birth, total (years)'}, 'country': {'id': 'KE', 'value': 'Kenya'}, 'countryiso3code': 'KEN', 'date': '2017', 'value': 67.291, 'unit': '', 'obs_status': '', 'decimal': 0}
# {'indicator': {'id': 'SP.DYN.LE00.IN', 'value': 'Life expectancy at birth, total (years)'}, 'country': {'id': 'KE', 'value': 'Kenya'}, 'countryiso3code': 'KEN', 'date': '2016', 'value': 67.032, 'unit': '', 'obs_status': '', 'decimal': 0}
# {'indicator': {'id': 'SP.DYN.LE00.IN', 'value': 'Life expectancy at birth, total (years)'}, 'country': {'id': 'KE', 'value': 'Kenya'}, 'countryiso3code': 'KEN', 'date': '2015', 'value': 66.695, 'unit': '', 'obs_status': '', 'decimal': 0}
# ...

# %%
df = pd.read_json("Resources/data/output_api_2.json")

# %%
df
# Out:
#     country                                indicator  percent  year
# 0     Kenya  Life expectancy at birth, total (years)      NaN  2018
# 1     Kenya  Life expectancy at birth, total (years)   67.291  2017
# 2     Kenya  Life expectancy at birth, total (years)   67.032  2016
# 3     Kenya  Life expectancy at birth, total (years)   66.695  2015
# 4     Kenya  Life expectancy at birth, total (years)   66.242  2014
# 5     Kenya  Life expectancy at birth, total (years)   65.651  2013
# 6     Kenya  Life expectancy at birth, total (years)   64.907  2012
# 7     Kenya  Life expectancy at birth, total (years)   64.008  2011
# 8     Kenya  Life expectancy at birth, total (years)   62.936  2010
# 9     Kenya  Life expectancy at birth, total (years)   61.680  2009
# 10    Kenya  Life expectancy at birth, total (years)   60.275  2008
# 11    Kenya  Life expectancy at birth, total (years)   58.784  2007
# 12    Kenya  Life expectancy at birth, total (years)   57.271  2006
# ...

# %%
engine = create_engine('mysql://root:root123@127.0.0.1:3306/life_db')

# %%
df.to_sql(name='life_expectancy', con=engine, if_exists = 'append', index=False)

# %%
pd.read_sql_query('select * from life_expectancy', con=engine).head()
# Out:
#   country                                indicator  percent  year
# 0   Kenya  Life expectancy at birth, total (years)      NaN  2018
# 1   Kenya  Life expectancy at birth, total (years)   67.291  2017
# 2   Kenya  Life expectancy at birth, total (years)   67.032  2016
# 3   Kenya  Life expectancy at birth, total (years)   66.695  2015
# 4   Kenya  Life expectancy at birth, total (years)   66.242  2014

# %%
# Finally putting transformed dataframe to csv file
df.to_csv('Resources/csv/life_expectancy.csv',index = True, header = True)
